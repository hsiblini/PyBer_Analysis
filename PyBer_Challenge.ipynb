# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
total_ride_count = pyber_data_df.groupby(["type"]).count()["ride_id"]
total_ride_count
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
# 2. Get the total drivers for each city type

total_driver_count = city_data_df.groupby(["type"]).sum()["driver_count"]

total_driver_count
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
total_fares = pyber_data_df.groupby(["type"]).sum()["fare"]
total_fares
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
average_fare = pyber_data_df.groupby(["type"]).mean()["fare"]
average_fare
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# Name: fare, dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
average_urban_driver_fare = total_fares[0]/total_driver_count[0]
average_suburban_driver_fare = total_fares[1]/total_driver_count[1]
average_rural_driver_fare = total_fares[2]/total_driver_count[2]

print (f"the average urban fare is {average_urban_driver_fare}.")
print (f"the average suburban fare is {average_suburban_driver_fare}.")
print (f"the average rural fare is {average_rural_driver_fare}.")

average_driver_fare = [average_rural_driver_fare, average_suburban_driver_fare, average_urban_driver_fare]
average_driver_fare
# Out:
# the average urban fare is 55.48628205128208.
# the average suburban fare is 39.50271428571431.
# the average rural fare is 16.57146777546781.
# [16.57146777546781, 39.50271428571431, 55.48628205128208]

# %%
pyber_summary = {"Total Rides" : total_ride_count,
                 "Total Drivers" : total_driver_count,
                 "Total Fares" : total_fares,
                 "Average Fare per Ride" : average_fare,
                 "Average Fare per Driver" : average_driver_fare
                 }
                 
pyber_summary_df = pd.DataFrame.from_dict(pyber_summary)
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# type
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# type
# Rural                   16.571468
# Suburban                39.502714
# Urban                   55.486282

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# Rural                   16.571468
# Suburban                39.502714
# Urban                   55.486282

# %%
#  8. Format the columns.

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])
pyber_data_df
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# ...

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.

total_fares_date = pyber_data_df.groupby(["type","date"]).sum()["fare"]
total_fares_date
# Out:
# type   date
# Rural  2019-01-01 09:45:36    43.69
#        2019-01-02 11:18:32    52.12
#        2019-01-03 19:51:01    19.90
#        2019-01-04 03:31:26    24.88
#        2019-01-06 07:38:40    47.33
#                               ...
# Urban  2019-05-08 04:20:00    21.99
#        2019-05-08 04:39:49    18.45
#        2019-05-08 07:29:01    18.55
#        2019-05-08 11:38:35    19.77
#        2019-05-08 13:10:18    18.04
# Name: fare, Length: 2375, dtype: float64

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
pyber_data_df = pyber_data_df.reset_index()

pyber_data_df
# Out:
#       index                city                 date   fare        ride_id  \
# 0         0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1         1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2         2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3         3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4         4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...     ...                 ...                  ...    ...            ...
# 2370   2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371   2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372   2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373   2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374   2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# ...

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
pyber_data_df = pyber_data_df.pivot ("date", "type", "fare")

pyber_data_df
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-05-08 04:20:00    NaN       NaN  21.99
# 2019-05-08 04:39:49    NaN       NaN  18.45
# 2019-05-08 07:29:01    NaN       NaN  18.55
# 2019-05-08 11:38:35    NaN       NaN  19.77
# 2019-05-08 13:10:18    NaN       NaN  18.04
#
# [2375 rows x 3 columns]

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.

pyber_data_df.loc['2019-01-01':'2019-04-29']
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-04-28 14:28:36    NaN       NaN  11.46
# 2019-04-28 16:29:16    NaN       NaN  36.42
# 2019-04-28 17:26:52    NaN       NaN  31.43
# 2019-04-28 17:38:09    NaN     34.87    NaN
# 2019-04-28 19:35:03    NaN     16.96    NaN
#
# [2196 rows x 3 columns]

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
pyber_data_df.index = pd.to_datetime(pyber_data_df.index)

pyber_data_df.index
# Out:
# DatetimeIndex(['2019-01-01 00:08:16', '2019-01-01 00:46:46',
#                '2019-01-01 02:07:24', '2019-01-01 03:46:50',
#                '2019-01-01 05:23:21', '2019-01-01 09:45:36',
#                '2019-01-01 12:32:48', '2019-01-01 14:40:14',
#                '2019-01-01 14:42:25', '2019-01-01 14:52:06',
#                ...
#                '2019-05-07 20:05:15', '2019-05-07 20:22:19',
#                '2019-05-07 20:40:29', '2019-05-08 01:54:18',
#                '2019-05-08 02:31:25', '2019-05-08 04:20:00',
#                '2019-05-08 04:39:49', '2019-05-08 07:29:01',
#                '2019-05-08 11:38:35', '2019-05-08 13:10:18'],
#               dtype='datetime64[ns]', name='date', length=2375, freq=None)

# %%
# 7. Check that the datatype for the index is datetime using df.info()

pyber_data_df.info("date")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2375 entries, 2019-01-01 00:08:16 to 2019-05-08 13:10:18
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     125 non-null    float64
#  1   Suburban  625 non-null    float64
#  2   Urban     1625 non-null   float64
# dtypes: float64(3)
# memory usage: 74.2 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.

pyber_data_df2 = pyber_data_df.resample("w").sum()
pyber_data_df2.head()
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.

pyber_data_df2.plot()
style.use('fivethirtyeight')
plt.title("Total Fare by City Type")
plt.ylabel("Fare ($USD)")
plt.savefig("analysis/PyBer_fare_summary.png")
